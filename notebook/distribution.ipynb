# %%
import pandas as pd

df = pd.read_parquet('challenge-dataset/data/validation-00000-of-00001.parquet')
video = ['VC', 'VA', 'VE']
df_1 = df[video]
df_1
# Out:
#     VC  VA  VE
# 0    1   3   1
# 1    1   1   2
# 2    1   2   1
# 3    0   3   1
# 4    2   3   2
# 5    1   2   2
# 6    2   3   3
# 7    0   1   0
# 8    3   3   2
# 9    1   3   1
# 10   1   1   0
# 11   2   3   2
